# %%
import cvxpy as cp
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import names 
import random
from itertools import product

# %%
def generate_scenario(num_resources, num_jobs, score_mu, score_sigma, seed, roles=None):
    '''
    Inputs: 
    Number of resources, Number of jobs, 
    mean and standard deviation of random normal scores distribution for resource-job assignments 
    Outputs: 
    random set of resources (first & last name),  
    random set of jobs, 
    job-assignment-scores dictionary (first & last name tuple keys, score values),
    job-assignment-costs dictionary (first & last name tuple keys, cost values),
    '''
    random.seed(seed)
    np.random.seed(seed)
    if roles is None:
        roles = {"Architect", "BackEndEngineer", "FrontEndEngineer",
                 "Tester", "DataScientist", "DataEngineer"}
    # P.D.F. of resource costs follows Benford's law, having support {1,2,...,9}
    # Benford's law states that in listings, tables of statistics, etc., the digit 1 tends to occur with probability ∼30%, 
    # much greater than the expected 11.1% (i.e., one digit out of 9). 
    # Benford's law can be observed, for instance, by examining tables of logarithms and noting that the first pages are much more worn and smudged than later pages. 
    benford = [np.log10((i+1)/i) for i in range(1,10)]
    # Sample resource names
    resources = {names.get_full_name(i) for i in range(num_resources)}
    # Sample job requirements, given that all roles are equally likely to be selected
    # multinomial arguments are numeber of experiments (jobs, here), probability of selecting a job and output shape
    req = np.random.multinomial(num_jobs, [1/len(roles)]*len(roles), size=1)[0] 
    jobs = set()
    # Assign ID to each job position
    for i, role in enumerate(roles):
        jobs = jobs.union(set(map(''.join, zip([role]*req[i], [str(x).zfill(int(np.log10(num_jobs))+1) 
                                                               for x in range(1,req[i]+1)]))))
    scores = {}
    costs = {}
    # Sample matching score and cost for each potential assignment
    for pair in product(resources, jobs):
        scores[pair] = int(np.clip(np.random.normal(score_mu, score_sigma), 0, 100))
        costs[pair] = random.choices(list(range(1,10)), weights=benford, k=1)[0]
    return resources, jobs, scores, costs

# %% [markdown]
# # Get Optimal Solution thru CVXPY implementation in the BAD WAY through dictionary variables!

# %%
def optimize(num_resources, num_jobs, score_mu, score_sigma, seed, roles, budget, job_gap_penalty):

    res, job, ms, cst = generate_scenario(num_resources, num_jobs, score_mu, score_sigma, seed, roles) 
    
    X = {}
    for a in ms.keys():
        X[a] = cp.Variable(boolean=True, name="assign")

    # Create a dictionary variable with jobs as keys and corresponding gap variables as values
    # gap binary to indicate not all jobs are necessarily filled due to budget cap;
    # 1 if a job is not filled and 0 otherwise
    G = {}
    for g in job:
        G[g] = cp.Variable(boolean=True, name="gap")

    # Create constraints.
    constraints = []

    # job constraint: for each job exactly one resource must be assigned to the job or
    # the corresponding gap variable must be set to 1:
    for j in job:
        X_r = 0
        for r in res:
            X_r += X[r, j]
        constraints += [
            X_r + G[j] == 1
            ]

    # resource constraint: for each resource, at most one job can be assigned to him/her:
    for r in res:
        X_j = 0
        for j in job:
            X_j += X[r, j]
        constraints += [
            X_j <= 1
        ]

    # budget constraint: cost of assigning resources to fill job requirements not to exceed budget
    constraints += [
        np.array(list(cst.values())) @ np.array(list(X.values())) <= budget,
    ]

    # Form objective.
    obj = cp.Maximize(np.array(list(ms.values())) @ np.array(list(X.values()))
                      - job_gap_penalty * cp.sum(list(G.values())))
    
    # Form and solve problem.
    prob = cp.Problem(obj, constraints)
    prob.solve(solver=cp.GUROBI, verbose=False) # or cp.CBC
    
    print("status:", prob.status)
    print("optimal value", prob.value)
    
    return X, G

# %%
res_job_assign, job_gap = optimize(
    num_resources=3, 
    num_jobs=3,
    score_mu=50, 
    score_sigma=15, 
    seed=10101, 
    roles=None, 
#     roles = {"Architect", "BackEndEngineer", "FrontEndEngineer",
#              "Tester", "DataScientist", "DataEngineer"}, 
    budget=10, 
    job_gap_penalty=101
        )
# Out:
# Academic license - for non-commercial use only - expires 2021-02-17
# Using license file C:\Users\mghan\gurobi.lic
# status: optimal
# optimal value 169.0

# %%
for k in res_job_assign:
    print(k, res_job_assign[k].value)
# Out:
# ('Gaye Botner', 'Architect1') 1.0
# ('Gaye Botner', 'DataScientist1') -0.0
# ('Gaye Botner', 'BackEndEngineer1') 0.0
# ('Karen Bartholomew', 'Architect1') -0.0
# ('Karen Bartholomew', 'DataScientist1') 1.0
# ('Karen Bartholomew', 'BackEndEngineer1') -0.0
# ('Garry Boston', 'Architect1') -0.0
# ('Garry Boston', 'DataScientist1') 0.0
# ('Garry Boston', 'BackEndEngineer1') 1.0

# %%
gap = 0
for k in job_gap:
    gap += job_gap[k].value
    print(k, job_gap[k].value)
print(str(int(gap)) + ' : Number of jobs could have not been assigned due to budget limit out of the total ' + str(len(job_gap)) + '.')
# Out:
# Architect1 -0.0
# DataScientist1 -0.0
# BackEndEngineer1 -0.0
# 0 : Number of jobs could have not been assigned due to budget limit out of the total 3.

# %% [markdown]
# # Efficient cvxpy implementation through matrix variables

# %%
def optimize(num_resources, num_jobs, score_mu, score_sigma, seed, roles, budget, job_gap_penalty):
    '''    
    call a function to generate random resources, jobs, assignmnet scores and costs
    and selects the optmial resource-job combinations to maximize performance score 
    with three contraints of budget, resource assignmnet to at most one job and
    job assigmnet to at most one resource
    
    '''
    res, job, ms, cst = generate_scenario(num_resources, num_jobs, score_mu, score_sigma, seed, roles) 
    
    
    assign_scores = np.array(list(ms.values())).reshape(len(res), len(job))
    assign_cost = np.array(list(cst.values())).reshape(len(res), len(job))
    x = cp.Variable(shape=(len(res), len(job)), boolean=True, name="assign")
    g = cp.Variable(shape=(len(job), ), boolean=True, name="gap")

    constraints = []
    constraints += [cp.sum(x[:, j]) + g[j] == 1 for j in range(len(job))]
    constraints += [cp.sum(x[r, :]) <= 1 for r in range(len(res))]
    constraints += [cp.sum(cp.multiply(assign_cost, x)) <= budget]

    job_gap_penalty=101
    obj = cp.Maximize(cp.sum(cp.multiply(assign_scores, x) - job_gap_penalty * cp.sum(g)))
    prob = cp.Problem(obj, constraints)
    prob.solve(solver=cp.GUROBI, verbose=True)
    
    res_job_assign = ms.copy()
    i = 0
    for key in res_job_assign.keys():
        i += 1
        res_job_assign[key] = x.value.astype(int).reshape(len(res_job_assign), ).tolist()[i - 1]
    
    job_not_filled = dict(zip(job, g.value.astype(int)))
    
    print("status: ", prob.status)
    print("optimal value: ", prob.value)
    print("Number of unfilled jobs: ", int(sum(g.value)))
    
    return x, g, job_not_filled, res_job_assign

# %%
res_job_assign_bool, job_gap_bool, job_gap, res_job_assign = optimize(
    num_resources=200, 
    num_jobs=200,
    score_mu=50, 
    score_sigma=15, 
    seed=10101, 
    roles=None, 
    budget=200, 
    job_gap_penalty=101
        )
# Out:
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 401 rows, 40200 columns and 120200 nonzeros
# Model fingerprint: 0x2db8da98
# Variable types: 0 continuous, 40200 integer (40200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 8.080000e+08
# Presolve time: 0.15s
# Presolved: 401 rows, 40200 columns, 120200 nonzeros
# Variable types: 0 continuous, 40200 integer (40200 binary)
#
# Root relaxation: objective -1.631200e+04, 600 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    -16312.00000 -16312.000  0.00%     -    0s
#
# Explored 0 nodes (600 simplex iterations) in 0.35 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -16312 8.08e+08
# No other solutions better than -16312
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.631200000000e+04, best bound -1.631200000000e+04, gap 0.0000%
# status:  optimal
# optimal value:  16312.0
# Number of unfilled jobs:  0

# %%
job_gap
# Out:
# {'Tester034': 0,
#  'DataScientist006': 0,
#  'DataEngineer023': 0,
#  'DataEngineer016': 0,
#  'BackEndEngineer014': 0,
#  'Tester036': 0,
#  'DataEngineer025': 0,
#  'DataScientist027': 0,
#  'DataEngineer010': 0,
#  'FrontEndEngineer001': 0,
#  'Architect009': 0,
#  'BackEndEngineer015': 0,
#  'Architect028': 0,
#  'DataScientist034': 0,
#  'Tester002': 0,
#  'BackEndEngineer005': 0,
#  'FrontEndEngineer015': 0,
#  'BackEndEngineer022': 0,
#  'DataScientist007': 0,
#  'Architect014': 0,
#  'DataEngineer007': 0,
#  'Architect017': 0,
#  'Tester025': 0,
#  'DataScientist031': 0,
#  'DataEngineer018': 0,
#  'DataScientist012': 0,
#  'DataEngineer017': 0,
#  'DataScientist021': 0,
#  'DataEngineer024': 0,
#  'FrontEndEngineer026': 0,
#  'FrontEndEngineer024': 0,
#  'Architect020': 0,
#  'Architect027': 0,
#  'FrontEndEngineer012': 0,
#  'DataEngineer009': 0,
#  'DataEngineer002': 0,
#  'BackEndEngineer017': 0,
#  'Tester031': 0,
#  'BackEndEngineer030': 0,
#  'DataScientist032': 0,
#  'Tester020': 0,
#  'Tester003': 0,
#  'Architect025': 0,
#  'Architect011': 0,
#  'Architect019': 0,
#  'BackEndEngineer010': 0,
#  'Tester027': 0,
#  'Tester012': 0,
#  'Tester022': 0,
#  'Tester033': 0,
#  'Architect024': 0,
#  'BackEndEngineer003': 0,
#  'DataScientist024': 0,
#  'Architect026': 0,
#  'Tester028': 0,
#  'DataScientist011': 0,
#  'FrontEndEngineer029': 0,
#  'BackEndEngineer013': 0,
#  'DataEngineer019': 0,
#  'Tester023': 0,
#  'DataScientist017': 0,
#  'Architect029': 0,
#  'FrontEndEngineer004': 0,
#  'DataScientist025': 0,
#  'DataScientist026': 0,
#  'Tester001': 0,
#  'BackEndEngineer016': 0,
#  'BackEndEngineer004': 0,
#  'FrontEndEngineer031': 0,
#  'DataScientist008': 0,
#  'DataScientist035': 0,
#  'FrontEndEngineer011': 0,
#  'Tester009': 0,
#  'FrontEndEngineer025': 0,
#  'DataEngineer011': 0,
#  'Tester015': 0,
#  'DataEngineer026': 0,
#  'BackEndEngineer024': 0,
#  'DataScientist010': 0,
#  'Tester029': 0,
#  'DataScientist015': 0,
#  'Tester035': 0,
#  'DataEngineer001': 0,
#  'BackEndEngineer011': 0,
#  'Tester006': 0,
#  'Tester011': 0,
#  'BackEndEngineer008': 0,
#  'BackEndEngineer012': 0,
#  'Tester016': 0,
#  'Tester013': 0,
#  'DataScientist033': 0,
#  'Tester007': 0,
#  'DataScientist036': 0,
#  'Tester017': 0,
#  'DataEngineer013': 0,
#  'FrontEndEngineer018': 0,
#  'DataScientist022': 0,
#  'Tester018': 0,
#  'FrontEndEngineer034': 0,
#  'FrontEndEngineer017': 0,
#  'FrontEndEngineer023': 0,
#  'Architect015': 0,
#  'Architect005': 0,
#  'BackEndEngineer027': 0,
#  'Architect003': 0,
#  'Tester004': 0,
#  'DataScientist013': 0,
#  'FrontEndEngineer013': 0,
#  'BackEndEngineer002': 0,
#  'Architect030': 0,
#  'Tester030': 0,
#  'Architect002': 0,
#  'DataScientist019': 0,
#  'DataEngineer022': 0,
#  'Tester024': 0,
#  'Tester021': 0,
#  'BackEndEngineer019': 0,
#  'DataEngineer008': 0,
#  'DataScientist003': 0,
#  'FrontEndEngineer021': 0,
#  'DataEngineer015': 0,
#  'Tester014': 0,
#  'FrontEndEngineer033': 0,
#  'BackEndEngineer018': 0,
#  'FrontEndEngineer007': 0,
#  'FrontEndEngineer008': 0,
#  'FrontEndEngineer020': 0,
#  'BackEndEngineer007': 0,
#  'FrontEndEngineer019': 0,
#  'Architect034': 0,
#  'DataScientist029': 0,
#  'Architect001': 0,
#  'BackEndEngineer001': 0,
#  'Architect007': 0,
#  'Architect031': 0,
#  'FrontEndEngineer028': 0,
#  'DataScientist002': 0,
#  'BackEndEngineer026': 0,
#  'Tester010': 0,
#  'Tester019': 0,
#  'DataEngineer006': 0,
#  'Architect018': 0,
#  'FrontEndEngineer010': 0,
#  'FrontEndEngineer022': 0,
#  'DataEngineer005': 0,
#  'DataEngineer003': 0,
#  'Architect006': 0,
#  'DataScientist016': 0,
#  'FrontEndEngineer014': 0,
#  'Tester038': 0,
#  'Architect022': 0,
#  'BackEndEngineer025': 0,
#  'DataScientist001': 0,
#  'Tester008': 0,
#  'DataScientist005': 0,
#  'DataScientist004': 0,
#  'FrontEndEngineer032': 0,
#  'Architect016': 0,
#  'FrontEndEngineer036': 0,
#  'DataScientist014': 0,
#  'Architect004': 0,
#  'BackEndEngineer020': 0,
#  'Tester037': 0,
#  'Architect032': 0,
#  'Architect033': 0,
#  'DataScientist018': 0,
#  'Architect021': 0,
#  'Architect013': 0,
#  'DataScientist009': 0,
#  'FrontEndEngineer003': 0,
#  'Architect023': 0,
#  'DataEngineer020': 0,
#  'Tester005': 0,
#  'FrontEndEngineer005': 0,
#  'BackEndEngineer028': 0,
#  'Tester026': 0,
#  'Tester032': 0,
#  'DataEngineer021': 0,
#  'DataEngineer004': 0,
#  'BackEndEngineer023': 0,
#  'BackEndEngineer029': 0,
#  'FrontEndEngineer030': 0,
#  'DataScientist030': 0,
#  'DataEngineer012': 0,
#  'FrontEndEngineer009': 0,
#  'FrontEndEngineer002': 0,
#  'DataScientist028': 0,
#  'FrontEndEngineer027': 0,
#  'BackEndEngineer009': 0,
#  'FrontEndEngineer006': 0,
#  'BackEndEngineer021': 0,
#  'FrontEndEngineer016': 0,
#  'Architect010': 0,
#  'BackEndEngineer006': 0,
#  'DataScientist023': 0,
#  'DataEngineer014': 0,
#  'DataScientist020': 0,
#  'Architect008': 0,
#  'Architect012': 0,
#  'FrontEndEngineer035': 0}

# %%
res_job_assign
# Out:
# {('Janice Rothrock', 'Tester034'): 0,
#  ('Janice Rothrock', 'DataScientist006'): 0,
#  ('Janice Rothrock', 'DataEngineer023'): 0,
#  ('Janice Rothrock', 'DataEngineer016'): 0,
#  ('Janice Rothrock', 'BackEndEngineer014'): 0,
#  ('Janice Rothrock', 'Tester036'): 0,
#  ('Janice Rothrock', 'DataEngineer025'): 0,
#  ('Janice Rothrock', 'DataScientist027'): 0,
#  ('Janice Rothrock', 'DataEngineer010'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer001'): 0,
#  ('Janice Rothrock', 'Architect009'): 0,
#  ('Janice Rothrock', 'BackEndEngineer015'): 0,
#  ('Janice Rothrock', 'Architect028'): 0,
#  ('Janice Rothrock', 'DataScientist034'): 0,
#  ('Janice Rothrock', 'Tester002'): 0,
#  ('Janice Rothrock', 'BackEndEngineer005'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer015'): 0,
#  ('Janice Rothrock', 'BackEndEngineer022'): 0,
#  ('Janice Rothrock', 'DataScientist007'): 0,
#  ('Janice Rothrock', 'Architect014'): 0,
#  ('Janice Rothrock', 'DataEngineer007'): 0,
#  ('Janice Rothrock', 'Architect017'): 0,
#  ('Janice Rothrock', 'Tester025'): 0,
#  ('Janice Rothrock', 'DataScientist031'): 0,
#  ('Janice Rothrock', 'DataEngineer018'): 0,
#  ('Janice Rothrock', 'DataScientist012'): 0,
#  ('Janice Rothrock', 'DataEngineer017'): 0,
#  ('Janice Rothrock', 'DataScientist021'): 0,
#  ('Janice Rothrock', 'DataEngineer024'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer026'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer024'): 0,
#  ('Janice Rothrock', 'Architect020'): 0,
#  ('Janice Rothrock', 'Architect027'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer012'): 0,
#  ('Janice Rothrock', 'DataEngineer009'): 0,
#  ('Janice Rothrock', 'DataEngineer002'): 0,
#  ('Janice Rothrock', 'BackEndEngineer017'): 0,
#  ('Janice Rothrock', 'Tester031'): 0,
#  ('Janice Rothrock', 'BackEndEngineer030'): 0,
#  ('Janice Rothrock', 'DataScientist032'): 0,
#  ('Janice Rothrock', 'Tester020'): 0,
#  ('Janice Rothrock', 'Tester003'): 0,
#  ('Janice Rothrock', 'Architect025'): 0,
#  ('Janice Rothrock', 'Architect011'): 0,
#  ('Janice Rothrock', 'Architect019'): 0,
#  ('Janice Rothrock', 'BackEndEngineer010'): 0,
#  ('Janice Rothrock', 'Tester027'): 0,
#  ('Janice Rothrock', 'Tester012'): 0,
#  ('Janice Rothrock', 'Tester022'): 0,
#  ('Janice Rothrock', 'Tester033'): 0,
#  ('Janice Rothrock', 'Architect024'): 0,
#  ('Janice Rothrock', 'BackEndEngineer003'): 0,
#  ('Janice Rothrock', 'DataScientist024'): 0,
#  ('Janice Rothrock', 'Architect026'): 0,
#  ('Janice Rothrock', 'Tester028'): 0,
#  ('Janice Rothrock', 'DataScientist011'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer029'): 0,
#  ('Janice Rothrock', 'BackEndEngineer013'): 0,
#  ('Janice Rothrock', 'DataEngineer019'): 0,
#  ('Janice Rothrock', 'Tester023'): 0,
#  ('Janice Rothrock', 'DataScientist017'): 0,
#  ('Janice Rothrock', 'Architect029'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer004'): 0,
#  ('Janice Rothrock', 'DataScientist025'): 0,
#  ('Janice Rothrock', 'DataScientist026'): 0,
#  ('Janice Rothrock', 'Tester001'): 0,
#  ('Janice Rothrock', 'BackEndEngineer016'): 0,
#  ('Janice Rothrock', 'BackEndEngineer004'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer031'): 0,
#  ('Janice Rothrock', 'DataScientist008'): 0,
#  ('Janice Rothrock', 'DataScientist035'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer011'): 0,
#  ('Janice Rothrock', 'Tester009'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer025'): 0,
#  ('Janice Rothrock', 'DataEngineer011'): 0,
#  ('Janice Rothrock', 'Tester015'): 0,
#  ('Janice Rothrock', 'DataEngineer026'): 0,
#  ('Janice Rothrock', 'BackEndEngineer024'): 0,
#  ('Janice Rothrock', 'DataScientist010'): 0,
#  ('Janice Rothrock', 'Tester029'): 0,
#  ('Janice Rothrock', 'DataScientist015'): 0,
#  ('Janice Rothrock', 'Tester035'): 0,
#  ('Janice Rothrock', 'DataEngineer001'): 0,
#  ('Janice Rothrock', 'BackEndEngineer011'): 0,
#  ('Janice Rothrock', 'Tester006'): 0,
#  ('Janice Rothrock', 'Tester011'): 0,
#  ('Janice Rothrock', 'BackEndEngineer008'): 0,
#  ('Janice Rothrock', 'BackEndEngineer012'): 0,
#  ('Janice Rothrock', 'Tester016'): 0,
#  ('Janice Rothrock', 'Tester013'): 0,
#  ('Janice Rothrock', 'DataScientist033'): 0,
#  ('Janice Rothrock', 'Tester007'): 0,
#  ('Janice Rothrock', 'DataScientist036'): 0,
#  ('Janice Rothrock', 'Tester017'): 0,
#  ('Janice Rothrock', 'DataEngineer013'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer018'): 0,
#  ('Janice Rothrock', 'DataScientist022'): 0,
#  ('Janice Rothrock', 'Tester018'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer034'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer017'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer023'): 0,
#  ('Janice Rothrock', 'Architect015'): 0,
#  ('Janice Rothrock', 'Architect005'): 0,
#  ('Janice Rothrock', 'BackEndEngineer027'): 0,
#  ('Janice Rothrock', 'Architect003'): 0,
#  ('Janice Rothrock', 'Tester004'): 0,
#  ('Janice Rothrock', 'DataScientist013'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer013'): 0,
#  ('Janice Rothrock', 'BackEndEngineer002'): 0,
#  ('Janice Rothrock', 'Architect030'): 0,
#  ('Janice Rothrock', 'Tester030'): 0,
#  ('Janice Rothrock', 'Architect002'): 0,
#  ('Janice Rothrock', 'DataScientist019'): 0,
#  ('Janice Rothrock', 'DataEngineer022'): 0,
#  ('Janice Rothrock', 'Tester024'): 0,
#  ('Janice Rothrock', 'Tester021'): 0,
#  ('Janice Rothrock', 'BackEndEngineer019'): 0,
#  ('Janice Rothrock', 'DataEngineer008'): 0,
#  ('Janice Rothrock', 'DataScientist003'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer021'): 0,
#  ('Janice Rothrock', 'DataEngineer015'): 0,
#  ('Janice Rothrock', 'Tester014'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer033'): 0,
#  ('Janice Rothrock', 'BackEndEngineer018'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer007'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer008'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer020'): 0,
#  ('Janice Rothrock', 'BackEndEngineer007'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer019'): 0,
#  ('Janice Rothrock', 'Architect034'): 0,
#  ('Janice Rothrock', 'DataScientist029'): 0,
#  ('Janice Rothrock', 'Architect001'): 0,
#  ('Janice Rothrock', 'BackEndEngineer001'): 0,
#  ('Janice Rothrock', 'Architect007'): 0,
#  ('Janice Rothrock', 'Architect031'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer028'): 0,
#  ('Janice Rothrock', 'DataScientist002'): 0,
#  ('Janice Rothrock', 'BackEndEngineer026'): 0,
#  ('Janice Rothrock', 'Tester010'): 0,
#  ('Janice Rothrock', 'Tester019'): 0,
#  ('Janice Rothrock', 'DataEngineer006'): 0,
#  ('Janice Rothrock', 'Architect018'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer010'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer022'): 0,
#  ('Janice Rothrock', 'DataEngineer005'): 0,
#  ('Janice Rothrock', 'DataEngineer003'): 0,
#  ('Janice Rothrock', 'Architect006'): 0,
#  ('Janice Rothrock', 'DataScientist016'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer014'): 0,
#  ('Janice Rothrock', 'Tester038'): 0,
#  ('Janice Rothrock', 'Architect022'): 0,
#  ('Janice Rothrock', 'BackEndEngineer025'): 0,
#  ('Janice Rothrock', 'DataScientist001'): 0,
#  ('Janice Rothrock', 'Tester008'): 0,
#  ('Janice Rothrock', 'DataScientist005'): 0,
#  ('Janice Rothrock', 'DataScientist004'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer032'): 0,
#  ('Janice Rothrock', 'Architect016'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer036'): 0,
#  ('Janice Rothrock', 'DataScientist014'): 0,
#  ('Janice Rothrock', 'Architect004'): 0,
#  ('Janice Rothrock', 'BackEndEngineer020'): 0,
#  ('Janice Rothrock', 'Tester037'): 0,
#  ('Janice Rothrock', 'Architect032'): 0,
#  ('Janice Rothrock', 'Architect033'): 0,
#  ('Janice Rothrock', 'DataScientist018'): 0,
#  ('Janice Rothrock', 'Architect021'): 0,
#  ('Janice Rothrock', 'Architect013'): 0,
#  ('Janice Rothrock', 'DataScientist009'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer003'): 0,
#  ('Janice Rothrock', 'Architect023'): 0,
#  ('Janice Rothrock', 'DataEngineer020'): 0,
#  ('Janice Rothrock', 'Tester005'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer005'): 0,
#  ('Janice Rothrock', 'BackEndEngineer028'): 0,
#  ('Janice Rothrock', 'Tester026'): 0,
#  ('Janice Rothrock', 'Tester032'): 0,
#  ('Janice Rothrock', 'DataEngineer021'): 0,
#  ('Janice Rothrock', 'DataEngineer004'): 0,
#  ('Janice Rothrock', 'BackEndEngineer023'): 0,
#  ('Janice Rothrock', 'BackEndEngineer029'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer030'): 0,
#  ('Janice Rothrock', 'DataScientist030'): 0,
#  ('Janice Rothrock', 'DataEngineer012'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer009'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer002'): 0,
#  ('Janice Rothrock', 'DataScientist028'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer027'): 0,
#  ('Janice Rothrock', 'BackEndEngineer009'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer006'): 0,
#  ('Janice Rothrock', 'BackEndEngineer021'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer016'): 0,
#  ('Janice Rothrock', 'Architect010'): 0,
#  ('Janice Rothrock', 'BackEndEngineer006'): 0,
#  ('Janice Rothrock', 'DataScientist023'): 0,
#  ('Janice Rothrock', 'DataEngineer014'): 0,
#  ('Janice Rothrock', 'DataScientist020'): 1,
#  ('Janice Rothrock', 'Architect008'): 0,
#  ('Janice Rothrock', 'Architect012'): 0,
#  ('Janice Rothrock', 'FrontEndEngineer035'): 0,
#  ('Timothy Spencer', 'Tester034'): 0,
#  ('Timothy Spencer', 'DataScientist006'): 0,
#  ('Timothy Spencer', 'DataEngineer023'): 0,
#  ('Timothy Spencer', 'DataEngineer016'): 0,
#  ('Timothy Spencer', 'BackEndEngineer014'): 0,
#  ('Timothy Spencer', 'Tester036'): 0,
#  ('Timothy Spencer', 'DataEngineer025'): 0,
#  ('Timothy Spencer', 'DataScientist027'): 0,
#  ('Timothy Spencer', 'DataEngineer010'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer001'): 0,
#  ('Timothy Spencer', 'Architect009'): 0,
#  ('Timothy Spencer', 'BackEndEngineer015'): 0,
#  ('Timothy Spencer', 'Architect028'): 0,
#  ('Timothy Spencer', 'DataScientist034'): 0,
#  ('Timothy Spencer', 'Tester002'): 0,
#  ('Timothy Spencer', 'BackEndEngineer005'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer015'): 0,
#  ('Timothy Spencer', 'BackEndEngineer022'): 0,
#  ('Timothy Spencer', 'DataScientist007'): 0,
#  ('Timothy Spencer', 'Architect014'): 0,
#  ('Timothy Spencer', 'DataEngineer007'): 0,
#  ('Timothy Spencer', 'Architect017'): 0,
#  ('Timothy Spencer', 'Tester025'): 0,
#  ('Timothy Spencer', 'DataScientist031'): 0,
#  ('Timothy Spencer', 'DataEngineer018'): 0,
#  ('Timothy Spencer', 'DataScientist012'): 0,
#  ('Timothy Spencer', 'DataEngineer017'): 0,
#  ('Timothy Spencer', 'DataScientist021'): 0,
#  ('Timothy Spencer', 'DataEngineer024'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer026'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer024'): 0,
#  ('Timothy Spencer', 'Architect020'): 0,
#  ('Timothy Spencer', 'Architect027'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer012'): 0,
#  ('Timothy Spencer', 'DataEngineer009'): 0,
#  ('Timothy Spencer', 'DataEngineer002'): 0,
#  ('Timothy Spencer', 'BackEndEngineer017'): 0,
#  ('Timothy Spencer', 'Tester031'): 0,
#  ('Timothy Spencer', 'BackEndEngineer030'): 0,
#  ('Timothy Spencer', 'DataScientist032'): 0,
#  ('Timothy Spencer', 'Tester020'): 0,
#  ('Timothy Spencer', 'Tester003'): 0,
#  ('Timothy Spencer', 'Architect025'): 0,
#  ('Timothy Spencer', 'Architect011'): 0,
#  ('Timothy Spencer', 'Architect019'): 0,
#  ('Timothy Spencer', 'BackEndEngineer010'): 0,
#  ('Timothy Spencer', 'Tester027'): 0,
#  ('Timothy Spencer', 'Tester012'): 0,
#  ('Timothy Spencer', 'Tester022'): 0,
#  ('Timothy Spencer', 'Tester033'): 0,
#  ('Timothy Spencer', 'Architect024'): 0,
#  ('Timothy Spencer', 'BackEndEngineer003'): 0,
#  ('Timothy Spencer', 'DataScientist024'): 0,
#  ('Timothy Spencer', 'Architect026'): 0,
#  ('Timothy Spencer', 'Tester028'): 1,
#  ('Timothy Spencer', 'DataScientist011'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer029'): 0,
#  ('Timothy Spencer', 'BackEndEngineer013'): 0,
#  ('Timothy Spencer', 'DataEngineer019'): 0,
#  ('Timothy Spencer', 'Tester023'): 0,
#  ('Timothy Spencer', 'DataScientist017'): 0,
#  ('Timothy Spencer', 'Architect029'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer004'): 0,
#  ('Timothy Spencer', 'DataScientist025'): 0,
#  ('Timothy Spencer', 'DataScientist026'): 0,
#  ('Timothy Spencer', 'Tester001'): 0,
#  ('Timothy Spencer', 'BackEndEngineer016'): 0,
#  ('Timothy Spencer', 'BackEndEngineer004'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer031'): 0,
#  ('Timothy Spencer', 'DataScientist008'): 0,
#  ('Timothy Spencer', 'DataScientist035'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer011'): 0,
#  ('Timothy Spencer', 'Tester009'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer025'): 0,
#  ('Timothy Spencer', 'DataEngineer011'): 0,
#  ('Timothy Spencer', 'Tester015'): 0,
#  ('Timothy Spencer', 'DataEngineer026'): 0,
#  ('Timothy Spencer', 'BackEndEngineer024'): 0,
#  ('Timothy Spencer', 'DataScientist010'): 0,
#  ('Timothy Spencer', 'Tester029'): 0,
#  ('Timothy Spencer', 'DataScientist015'): 0,
#  ('Timothy Spencer', 'Tester035'): 0,
#  ('Timothy Spencer', 'DataEngineer001'): 0,
#  ('Timothy Spencer', 'BackEndEngineer011'): 0,
#  ('Timothy Spencer', 'Tester006'): 0,
#  ('Timothy Spencer', 'Tester011'): 0,
#  ('Timothy Spencer', 'BackEndEngineer008'): 0,
#  ('Timothy Spencer', 'BackEndEngineer012'): 0,
#  ('Timothy Spencer', 'Tester016'): 0,
#  ('Timothy Spencer', 'Tester013'): 0,
#  ('Timothy Spencer', 'DataScientist033'): 0,
#  ('Timothy Spencer', 'Tester007'): 0,
#  ('Timothy Spencer', 'DataScientist036'): 0,
#  ('Timothy Spencer', 'Tester017'): 0,
#  ('Timothy Spencer', 'DataEngineer013'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer018'): 0,
#  ('Timothy Spencer', 'DataScientist022'): 0,
#  ('Timothy Spencer', 'Tester018'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer034'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer017'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer023'): 0,
#  ('Timothy Spencer', 'Architect015'): 0,
#  ('Timothy Spencer', 'Architect005'): 0,
#  ('Timothy Spencer', 'BackEndEngineer027'): 0,
#  ('Timothy Spencer', 'Architect003'): 0,
#  ('Timothy Spencer', 'Tester004'): 0,
#  ('Timothy Spencer', 'DataScientist013'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer013'): 0,
#  ('Timothy Spencer', 'BackEndEngineer002'): 0,
#  ('Timothy Spencer', 'Architect030'): 0,
#  ('Timothy Spencer', 'Tester030'): 0,
#  ('Timothy Spencer', 'Architect002'): 0,
#  ('Timothy Spencer', 'DataScientist019'): 0,
#  ('Timothy Spencer', 'DataEngineer022'): 0,
#  ('Timothy Spencer', 'Tester024'): 0,
#  ('Timothy Spencer', 'Tester021'): 0,
#  ('Timothy Spencer', 'BackEndEngineer019'): 0,
#  ('Timothy Spencer', 'DataEngineer008'): 0,
#  ('Timothy Spencer', 'DataScientist003'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer021'): 0,
#  ('Timothy Spencer', 'DataEngineer015'): 0,
#  ('Timothy Spencer', 'Tester014'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer033'): 0,
#  ('Timothy Spencer', 'BackEndEngineer018'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer007'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer008'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer020'): 0,
#  ('Timothy Spencer', 'BackEndEngineer007'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer019'): 0,
#  ('Timothy Spencer', 'Architect034'): 0,
#  ('Timothy Spencer', 'DataScientist029'): 0,
#  ('Timothy Spencer', 'Architect001'): 0,
#  ('Timothy Spencer', 'BackEndEngineer001'): 0,
#  ('Timothy Spencer', 'Architect007'): 0,
#  ('Timothy Spencer', 'Architect031'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer028'): 0,
#  ('Timothy Spencer', 'DataScientist002'): 0,
#  ('Timothy Spencer', 'BackEndEngineer026'): 0,
#  ('Timothy Spencer', 'Tester010'): 0,
#  ('Timothy Spencer', 'Tester019'): 0,
#  ('Timothy Spencer', 'DataEngineer006'): 0,
#  ('Timothy Spencer', 'Architect018'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer010'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer022'): 0,
#  ('Timothy Spencer', 'DataEngineer005'): 0,
#  ('Timothy Spencer', 'DataEngineer003'): 0,
#  ('Timothy Spencer', 'Architect006'): 0,
#  ('Timothy Spencer', 'DataScientist016'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer014'): 0,
#  ('Timothy Spencer', 'Tester038'): 0,
#  ('Timothy Spencer', 'Architect022'): 0,
#  ('Timothy Spencer', 'BackEndEngineer025'): 0,
#  ('Timothy Spencer', 'DataScientist001'): 0,
#  ('Timothy Spencer', 'Tester008'): 0,
#  ('Timothy Spencer', 'DataScientist005'): 0,
#  ('Timothy Spencer', 'DataScientist004'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer032'): 0,
#  ('Timothy Spencer', 'Architect016'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer036'): 0,
#  ('Timothy Spencer', 'DataScientist014'): 0,
#  ('Timothy Spencer', 'Architect004'): 0,
#  ('Timothy Spencer', 'BackEndEngineer020'): 0,
#  ('Timothy Spencer', 'Tester037'): 0,
#  ('Timothy Spencer', 'Architect032'): 0,
#  ('Timothy Spencer', 'Architect033'): 0,
#  ('Timothy Spencer', 'DataScientist018'): 0,
#  ('Timothy Spencer', 'Architect021'): 0,
#  ('Timothy Spencer', 'Architect013'): 0,
#  ('Timothy Spencer', 'DataScientist009'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer003'): 0,
#  ('Timothy Spencer', 'Architect023'): 0,
#  ('Timothy Spencer', 'DataEngineer020'): 0,
#  ('Timothy Spencer', 'Tester005'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer005'): 0,
#  ('Timothy Spencer', 'BackEndEngineer028'): 0,
#  ('Timothy Spencer', 'Tester026'): 0,
#  ('Timothy Spencer', 'Tester032'): 0,
#  ('Timothy Spencer', 'DataEngineer021'): 0,
#  ('Timothy Spencer', 'DataEngineer004'): 0,
#  ('Timothy Spencer', 'BackEndEngineer023'): 0,
#  ('Timothy Spencer', 'BackEndEngineer029'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer030'): 0,
#  ('Timothy Spencer', 'DataScientist030'): 0,
#  ('Timothy Spencer', 'DataEngineer012'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer009'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer002'): 0,
#  ('Timothy Spencer', 'DataScientist028'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer027'): 0,
#  ('Timothy Spencer', 'BackEndEngineer009'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer006'): 0,
#  ('Timothy Spencer', 'BackEndEngineer021'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer016'): 0,
#  ('Timothy Spencer', 'Architect010'): 0,
#  ('Timothy Spencer', 'BackEndEngineer006'): 0,
#  ('Timothy Spencer', 'DataScientist023'): 0,
#  ('Timothy Spencer', 'DataEngineer014'): 0,
#  ('Timothy Spencer', 'DataScientist020'): 0,
#  ('Timothy Spencer', 'Architect008'): 0,
#  ('Timothy Spencer', 'Architect012'): 0,
#  ('Timothy Spencer', 'FrontEndEngineer035'): 0,
#  ('Basil Lander', 'Tester034'): 0,
#  ('Basil Lander', 'DataScientist006'): 0,
#  ('Basil Lander', 'DataEngineer023'): 0,
#  ('Basil Lander', 'DataEngineer016'): 0,
#  ('Basil Lander', 'BackEndEngineer014'): 0,
#  ('Basil Lander', 'Tester036'): 0,
#  ('Basil Lander', 'DataEngineer025'): 0,
#  ('Basil Lander', 'DataScientist027'): 0,
#  ('Basil Lander', 'DataEngineer010'): 0,
#  ('Basil Lander', 'FrontEndEngineer001'): 0,
#  ('Basil Lander', 'Architect009'): 0,
#  ('Basil Lander', 'BackEndEngineer015'): 0,
#  ('Basil Lander', 'Architect028'): 0,
#  ('Basil Lander', 'DataScientist034'): 0,
#  ('Basil Lander', 'Tester002'): 0,
#  ('Basil Lander', 'BackEndEngineer005'): 0,
#  ('Basil Lander', 'FrontEndEngineer015'): 0,
#  ('Basil Lander', 'BackEndEngineer022'): 0,
#  ('Basil Lander', 'DataScientist007'): 0,
#  ('Basil Lander', 'Architect014'): 0,
#  ('Basil Lander', 'DataEngineer007'): 0,
#  ('Basil Lander', 'Architect017'): 0,
#  ('Basil Lander', 'Tester025'): 0,
#  ('Basil Lander', 'DataScientist031'): 0,
#  ('Basil Lander', 'DataEngineer018'): 0,
#  ('Basil Lander', 'DataScientist012'): 0,
#  ('Basil Lander', 'DataEngineer017'): 0,
#  ('Basil Lander', 'DataScientist021'): 0,
#  ('Basil Lander', 'DataEngineer024'): 0,
#  ('Basil Lander', 'FrontEndEngineer026'): 0,
#  ('Basil Lander', 'FrontEndEngineer024'): 0,
#  ('Basil Lander', 'Architect020'): 0,
#  ('Basil Lander', 'Architect027'): 0,
#  ('Basil Lander', 'FrontEndEngineer012'): 0,
#  ('Basil Lander', 'DataEngineer009'): 0,
#  ('Basil Lander', 'DataEngineer002'): 0,
#  ('Basil Lander', 'BackEndEngineer017'): 0,
#  ('Basil Lander', 'Tester031'): 0,
#  ('Basil Lander', 'BackEndEngineer030'): 0,
#  ('Basil Lander', 'DataScientist032'): 0,
#  ('Basil Lander', 'Tester020'): 0,
#  ('Basil Lander', 'Tester003'): 0,
#  ('Basil Lander', 'Architect025'): 0,
#  ('Basil Lander', 'Architect011'): 0,
#  ('Basil Lander', 'Architect019'): 0,
#  ('Basil Lander', 'BackEndEngineer010'): 0,
#  ('Basil Lander', 'Tester027'): 0,
#  ('Basil Lander', 'Tester012'): 0,
#  ('Basil Lander', 'Tester022'): 0,
#  ('Basil Lander', 'Tester033'): 0,
#  ('Basil Lander', 'Architect024'): 0,
#  ('Basil Lander', 'BackEndEngineer003'): 0,
#  ('Basil Lander', 'DataScientist024'): 0,
#  ('Basil Lander', 'Architect026'): 0,
#  ('Basil Lander', 'Tester028'): 0,
#  ('Basil Lander', 'DataScientist011'): 0,
#  ('Basil Lander', 'FrontEndEngineer029'): 0,
#  ('Basil Lander', 'BackEndEngineer013'): 0,
#  ('Basil Lander', 'DataEngineer019'): 0,
#  ('Basil Lander', 'Tester023'): 0,
#  ('Basil Lander', 'DataScientist017'): 0,
#  ('Basil Lander', 'Architect029'): 0,
#  ('Basil Lander', 'FrontEndEngineer004'): 0,
#  ('Basil Lander', 'DataScientist025'): 0,
#  ('Basil Lander', 'DataScientist026'): 0,
#  ('Basil Lander', 'Tester001'): 0,
#  ('Basil Lander', 'BackEndEngineer016'): 0,
#  ('Basil Lander', 'BackEndEngineer004'): 0,
#  ('Basil Lander', 'FrontEndEngineer031'): 0,
#  ('Basil Lander', 'DataScientist008'): 0,
#  ('Basil Lander', 'DataScientist035'): 0,
#  ('Basil Lander', 'FrontEndEngineer011'): 0,
#  ('Basil Lander', 'Tester009'): 0,
#  ('Basil Lander', 'FrontEndEngineer025'): 0,
#  ('Basil Lander', 'DataEngineer011'): 1,
#  ('Basil Lander', 'Tester015'): 0,
#  ('Basil Lander', 'DataEngineer026'): 0,
#  ('Basil Lander', 'BackEndEngineer024'): 0,
#  ('Basil Lander', 'DataScientist010'): 0,
#  ('Basil Lander', 'Tester029'): 0,
#  ('Basil Lander', 'DataScientist015'): 0,
#  ('Basil Lander', 'Tester035'): 0,
#  ('Basil Lander', 'DataEngineer001'): 0,
#  ('Basil Lander', 'BackEndEngineer011'): 0,
#  ('Basil Lander', 'Tester006'): 0,
#  ('Basil Lander', 'Tester011'): 0,
#  ('Basil Lander', 'BackEndEngineer008'): 0,
#  ('Basil Lander', 'BackEndEngineer012'): 0,
#  ('Basil Lander', 'Tester016'): 0,
#  ('Basil Lander', 'Tester013'): 0,
#  ('Basil Lander', 'DataScientist033'): 0,
#  ('Basil Lander', 'Tester007'): 0,
#  ('Basil Lander', 'DataScientist036'): 0,
#  ('Basil Lander', 'Tester017'): 0,
#  ('Basil Lander', 'DataEngineer013'): 0,
#  ('Basil Lander', 'FrontEndEngineer018'): 0,
#  ('Basil Lander', 'DataScientist022'): 0,
#  ('Basil Lander', 'Tester018'): 0,
#  ('Basil Lander', 'FrontEndEngineer034'): 0,
#  ('Basil Lander', 'FrontEndEngineer017'): 0,
#  ('Basil Lander', 'FrontEndEngineer023'): 0,
#  ('Basil Lander', 'Architect015'): 0,
#  ('Basil Lander', 'Architect005'): 0,
#  ('Basil Lander', 'BackEndEngineer027'): 0,
#  ('Basil Lander', 'Architect003'): 0,
#  ('Basil Lander', 'Tester004'): 0,
#  ('Basil Lander', 'DataScientist013'): 0,
#  ('Basil Lander', 'FrontEndEngineer013'): 0,
#  ('Basil Lander', 'BackEndEngineer002'): 0,
#  ('Basil Lander', 'Architect030'): 0,
#  ('Basil Lander', 'Tester030'): 0,
#  ('Basil Lander', 'Architect002'): 0,
#  ('Basil Lander', 'DataScientist019'): 0,
#  ('Basil Lander', 'DataEngineer022'): 0,
#  ('Basil Lander', 'Tester024'): 0,
#  ('Basil Lander', 'Tester021'): 0,
#  ('Basil Lander', 'BackEndEngineer019'): 0,
#  ('Basil Lander', 'DataEngineer008'): 0,
#  ('Basil Lander', 'DataScientist003'): 0,
#  ('Basil Lander', 'FrontEndEngineer021'): 0,
#  ('Basil Lander', 'DataEngineer015'): 0,
#  ('Basil Lander', 'Tester014'): 0,
#  ('Basil Lander', 'FrontEndEngineer033'): 0,
#  ('Basil Lander', 'BackEndEngineer018'): 0,
#  ('Basil Lander', 'FrontEndEngineer007'): 0,
#  ('Basil Lander', 'FrontEndEngineer008'): 0,
#  ('Basil Lander', 'FrontEndEngineer020'): 0,
#  ('Basil Lander', 'BackEndEngineer007'): 0,
#  ('Basil Lander', 'FrontEndEngineer019'): 0,
#  ('Basil Lander', 'Architect034'): 0,
#  ('Basil Lander', 'DataScientist029'): 0,
#  ('Basil Lander', 'Architect001'): 0,
#  ('Basil Lander', 'BackEndEngineer001'): 0,
#  ('Basil Lander', 'Architect007'): 0,
#  ('Basil Lander', 'Architect031'): 0,
#  ('Basil Lander', 'FrontEndEngineer028'): 0,
#  ('Basil Lander', 'DataScientist002'): 0,
#  ('Basil Lander', 'BackEndEngineer026'): 0,
#  ('Basil Lander', 'Tester010'): 0,
#  ('Basil Lander', 'Tester019'): 0,
#  ('Basil Lander', 'DataEngineer006'): 0,
#  ('Basil Lander', 'Architect018'): 0,
#  ('Basil Lander', 'FrontEndEngineer010'): 0,
#  ('Basil Lander', 'FrontEndEngineer022'): 0,
#  ('Basil Lander', 'DataEngineer005'): 0,
#  ('Basil Lander', 'DataEngineer003'): 0,
#  ('Basil Lander', 'Architect006'): 0,
#  ('Basil Lander', 'DataScientist016'): 0,
#  ('Basil Lander', 'FrontEndEngineer014'): 0,
#  ('Basil Lander', 'Tester038'): 0,
#  ('Basil Lander', 'Architect022'): 0,
#  ('Basil Lander', 'BackEndEngineer025'): 0,
#  ('Basil Lander', 'DataScientist001'): 0,
#  ('Basil Lander', 'Tester008'): 0,
#  ('Basil Lander', 'DataScientist005'): 0,
#  ('Basil Lander', 'DataScientist004'): 0,
#  ('Basil Lander', 'FrontEndEngineer032'): 0,
#  ('Basil Lander', 'Architect016'): 0,
#  ('Basil Lander', 'FrontEndEngineer036'): 0,
#  ('Basil Lander', 'DataScientist014'): 0,
#  ('Basil Lander', 'Architect004'): 0,
#  ('Basil Lander', 'BackEndEngineer020'): 0,
#  ('Basil Lander', 'Tester037'): 0,
#  ('Basil Lander', 'Architect032'): 0,
#  ('Basil Lander', 'Architect033'): 0,
#  ('Basil Lander', 'DataScientist018'): 0,
#  ('Basil Lander', 'Architect021'): 0,
#  ('Basil Lander', 'Architect013'): 0,
#  ('Basil Lander', 'DataScientist009'): 0,
#  ('Basil Lander', 'FrontEndEngineer003'): 0,
#  ('Basil Lander', 'Architect023'): 0,
#  ('Basil Lander', 'DataEngineer020'): 0,
#  ('Basil Lander', 'Tester005'): 0,
#  ('Basil Lander', 'FrontEndEngineer005'): 0,
#  ('Basil Lander', 'BackEndEngineer028'): 0,
#  ('Basil Lander', 'Tester026'): 0,
#  ('Basil Lander', 'Tester032'): 0,
#  ('Basil Lander', 'DataEngineer021'): 0,
#  ('Basil Lander', 'DataEngineer004'): 0,
#  ('Basil Lander', 'BackEndEngineer023'): 0,
#  ('Basil Lander', 'BackEndEngineer029'): 0,
#  ('Basil Lander', 'FrontEndEngineer030'): 0,
#  ('Basil Lander', 'DataScientist030'): 0,
#  ('Basil Lander', 'DataEngineer012'): 0,
#  ('Basil Lander', 'FrontEndEngineer009'): 0,
#  ('Basil Lander', 'FrontEndEngineer002'): 0,
#  ('Basil Lander', 'DataScientist028'): 0,
#  ('Basil Lander', 'FrontEndEngineer027'): 0,
#  ('Basil Lander', 'BackEndEngineer009'): 0,
#  ('Basil Lander', 'FrontEndEngineer006'): 0,
#  ('Basil Lander', 'BackEndEngineer021'): 0,
#  ('Basil Lander', 'FrontEndEngineer016'): 0,
#  ('Basil Lander', 'Architect010'): 0,
#  ('Basil Lander', 'BackEndEngineer006'): 0,
#  ('Basil Lander', 'DataScientist023'): 0,
#  ('Basil Lander', 'DataEngineer014'): 0,
#  ('Basil Lander', 'DataScientist020'): 0,
#  ('Basil Lander', 'Architect008'): 0,
#  ('Basil Lander', 'Architect012'): 0,
#  ('Basil Lander', 'FrontEndEngineer035'): 0,
#  ('Gale Brewer', 'Tester034'): 0,
#  ('Gale Brewer', 'DataScientist006'): 0,
#  ('Gale Brewer', 'DataEngineer023'): 0,
#  ('Gale Brewer', 'DataEngineer016'): 0,
#  ('Gale Brewer', 'BackEndEngineer014'): 0,
#  ('Gale Brewer', 'Tester036'): 0,
#  ('Gale Brewer', 'DataEngineer025'): 0,
#  ('Gale Brewer', 'DataScientist027'): 0,
#  ('Gale Brewer', 'DataEngineer010'): 0,
#  ('Gale Brewer', 'FrontEndEngineer001'): 0,
#  ('Gale Brewer', 'Architect009'): 0,
#  ('Gale Brewer', 'BackEndEngineer015'): 0,
#  ('Gale Brewer', 'Architect028'): 0,
#  ('Gale Brewer', 'DataScientist034'): 0,
#  ('Gale Brewer', 'Tester002'): 0,
#  ('Gale Brewer', 'BackEndEngineer005'): 0,
#  ('Gale Brewer', 'FrontEndEngineer015'): 0,
#  ('Gale Brewer', 'BackEndEngineer022'): 0,
#  ('Gale Brewer', 'DataScientist007'): 0,
#  ('Gale Brewer', 'Architect014'): 0,
#  ('Gale Brewer', 'DataEngineer007'): 0,
#  ('Gale Brewer', 'Architect017'): 0,
#  ('Gale Brewer', 'Tester025'): 0,
#  ('Gale Brewer', 'DataScientist031'): 0,
#  ('Gale Brewer', 'DataEngineer018'): 0,
#  ('Gale Brewer', 'DataScientist012'): 0,
#  ('Gale Brewer', 'DataEngineer017'): 0,
#  ('Gale Brewer', 'DataScientist021'): 0,
#  ('Gale Brewer', 'DataEngineer024'): 0,
#  ('Gale Brewer', 'FrontEndEngineer026'): 0,
#  ('Gale Brewer', 'FrontEndEngineer024'): 0,
#  ('Gale Brewer', 'Architect020'): 0,
#  ('Gale Brewer', 'Architect027'): 0,
#  ('Gale Brewer', 'FrontEndEngineer012'): 0,
#  ('Gale Brewer', 'DataEngineer009'): 0,
#  ('Gale Brewer', 'DataEngineer002'): 0,
#  ('Gale Brewer', 'BackEndEngineer017'): 0,
#  ('Gale Brewer', 'Tester031'): 0,
#  ('Gale Brewer', 'BackEndEngineer030'): 0,
#  ('Gale Brewer', 'DataScientist032'): 0,
#  ('Gale Brewer', 'Tester020'): 0,
#  ('Gale Brewer', 'Tester003'): 0,
#  ('Gale Brewer', 'Architect025'): 0,
#  ('Gale Brewer', 'Architect011'): 0,
#  ('Gale Brewer', 'Architect019'): 0,
#  ('Gale Brewer', 'BackEndEngineer010'): 0,
#  ('Gale Brewer', 'Tester027'): 0,
#  ('Gale Brewer', 'Tester012'): 0,
#  ('Gale Brewer', 'Tester022'): 0,
#  ('Gale Brewer', 'Tester033'): 0,
#  ('Gale Brewer', 'Architect024'): 0,
#  ('Gale Brewer', 'BackEndEngineer003'): 0,
#  ('Gale Brewer', 'DataScientist024'): 0,
#  ('Gale Brewer', 'Architect026'): 0,
#  ('Gale Brewer', 'Tester028'): 0,
#  ('Gale Brewer', 'DataScientist011'): 0,
#  ('Gale Brewer', 'FrontEndEngineer029'): 0,
#  ('Gale Brewer', 'BackEndEngineer013'): 0,
#  ('Gale Brewer', 'DataEngineer019'): 0,
#  ('Gale Brewer', 'Tester023'): 0,
#  ('Gale Brewer', 'DataScientist017'): 0,
#  ('Gale Brewer', 'Architect029'): 0,
#  ('Gale Brewer', 'FrontEndEngineer004'): 0,
#  ('Gale Brewer', 'DataScientist025'): 0,
#  ('Gale Brewer', 'DataScientist026'): 0,
#  ('Gale Brewer', 'Tester001'): 0,
#  ('Gale Brewer', 'BackEndEngineer016'): 0,
#  ('Gale Brewer', 'BackEndEngineer004'): 0,
#  ('Gale Brewer', 'FrontEndEngineer031'): 0,
#  ('Gale Brewer', 'DataScientist008'): 0,
#  ('Gale Brewer', 'DataScientist035'): 0,
#  ('Gale Brewer', 'FrontEndEngineer011'): 0,
#  ('Gale Brewer', 'Tester009'): 0,
#  ('Gale Brewer', 'FrontEndEngineer025'): 0,
#  ('Gale Brewer', 'DataEngineer011'): 0,
#  ('Gale Brewer', 'Tester015'): 0,
#  ('Gale Brewer', 'DataEngineer026'): 0,
#  ('Gale Brewer', 'BackEndEngineer024'): 0,
#  ('Gale Brewer', 'DataScientist010'): 0,
#  ('Gale Brewer', 'Tester029'): 0,
#  ('Gale Brewer', 'DataScientist015'): 0,
#  ('Gale Brewer', 'Tester035'): 0,
#  ('Gale Brewer', 'DataEngineer001'): 0,
#  ('Gale Brewer', 'BackEndEngineer011'): 0,
#  ('Gale Brewer', 'Tester006'): 0,
#  ('Gale Brewer', 'Tester011'): 0,
#  ('Gale Brewer', 'BackEndEngineer008'): 0,
#  ('Gale Brewer', 'BackEndEngineer012'): 0,
#  ('Gale Brewer', 'Tester016'): 0,
#  ('Gale Brewer', 'Tester013'): 0,
#  ('Gale Brewer', 'DataScientist033'): 0,
#  ('Gale Brewer', 'Tester007'): 0,
#  ('Gale Brewer', 'DataScientist036'): 0,
#  ('Gale Brewer', 'Tester017'): 0,
#  ('Gale Brewer', 'DataEngineer013'): 0,
#  ('Gale Brewer', 'FrontEndEngineer018'): 0,
#  ('Gale Brewer', 'DataScientist022'): 0,
#  ('Gale Brewer', 'Tester018'): 0,
#  ('Gale Brewer', 'FrontEndEngineer034'): 0,
#  ('Gale Brewer', 'FrontEndEngineer017'): 0,
#  ('Gale Brewer', 'FrontEndEngineer023'): 0,
#  ('Gale Brewer', 'Architect015'): 0,
#  ('Gale Brewer', 'Architect005'): 0,
#  ('Gale Brewer', 'BackEndEngineer027'): 0,
#  ('Gale Brewer', 'Architect003'): 0,
#  ('Gale Brewer', 'Tester004'): 0,
#  ('Gale Brewer', 'DataScientist013'): 0,
#  ('Gale Brewer', 'FrontEndEngineer013'): 0,
#  ('Gale Brewer', 'BackEndEngineer002'): 0,
#  ('Gale Brewer', 'Architect030'): 0,
#  ('Gale Brewer', 'Tester030'): 0,
#  ('Gale Brewer', 'Architect002'): 0,
#  ('Gale Brewer', 'DataScientist019'): 0,
#  ('Gale Brewer', 'DataEngineer022'): 0,
#  ('Gale Brewer', 'Tester024'): 0,
#  ('Gale Brewer', 'Tester021'): 0,
#  ('Gale Brewer', 'BackEndEngineer019'): 0,
#  ('Gale Brewer', 'DataEngineer008'): 0,
#  ('Gale Brewer', 'DataScientist003'): 0,
#  ('Gale Brewer', 'FrontEndEngineer021'): 0,
#  ('Gale Brewer', 'DataEngineer015'): 0,
#  ('Gale Brewer', 'Tester014'): 0,
#  ('Gale Brewer', 'FrontEndEngineer033'): 0,
#  ('Gale Brewer', 'BackEndEngineer018'): 0,
#  ('Gale Brewer', 'FrontEndEngineer007'): 0,
#  ('Gale Brewer', 'FrontEndEngineer008'): 0,
#  ('Gale Brewer', 'FrontEndEngineer020'): 0,
#  ('Gale Brewer', 'BackEndEngineer007'): 0,
#  ('Gale Brewer', 'FrontEndEngineer019'): 0,
#  ('Gale Brewer', 'Architect034'): 0,
#  ('Gale Brewer', 'DataScientist029'): 0,
#  ('Gale Brewer', 'Architect001'): 0,
#  ('Gale Brewer', 'BackEndEngineer001'): 0,
#  ('Gale Brewer', 'Architect007'): 0,
#  ('Gale Brewer', 'Architect031'): 0,
#  ('Gale Brewer', 'FrontEndEngineer028'): 0,
#  ('Gale Brewer', 'DataScientist002'): 0,
#  ('Gale Brewer', 'BackEndEngineer026'): 0,
#  ('Gale Brewer', 'Tester010'): 0,
#  ('Gale Brewer', 'Tester019'): 0,
#  ('Gale Brewer', 'DataEngineer006'): 0,
#  ('Gale Brewer', 'Architect018'): 0,
#  ('Gale Brewer', 'FrontEndEngineer010'): 0,
#  ('Gale Brewer', 'FrontEndEngineer022'): 0,
#  ('Gale Brewer', 'DataEngineer005'): 0,
#  ('Gale Brewer', 'DataEngineer003'): 0,
#  ('Gale Brewer', 'Architect006'): 0,
#  ('Gale Brewer', 'DataScientist016'): 1,
#  ('Gale Brewer', 'FrontEndEngineer014'): 0,
#  ('Gale Brewer', 'Tester038'): 0,
#  ('Gale Brewer', 'Architect022'): 0,
#  ('Gale Brewer', 'BackEndEngineer025'): 0,
#  ('Gale Brewer', 'DataScientist001'): 0,
#  ('Gale Brewer', 'Tester008'): 0,
#  ('Gale Brewer', 'DataScientist005'): 0,
#  ('Gale Brewer', 'DataScientist004'): 0,
#  ('Gale Brewer', 'FrontEndEngineer032'): 0,
#  ('Gale Brewer', 'Architect016'): 0,
#  ('Gale Brewer', 'FrontEndEngineer036'): 0,
#  ('Gale Brewer', 'DataScientist014'): 0,
#  ('Gale Brewer', 'Architect004'): 0,
#  ('Gale Brewer', 'BackEndEngineer020'): 0,
#  ('Gale Brewer', 'Tester037'): 0,
#  ('Gale Brewer', 'Architect032'): 0,
#  ('Gale Brewer', 'Architect033'): 0,
#  ('Gale Brewer', 'DataScientist018'): 0,
#  ('Gale Brewer', 'Architect021'): 0,
#  ('Gale Brewer', 'Architect013'): 0,
#  ('Gale Brewer', 'DataScientist009'): 0,
#  ('Gale Brewer', 'FrontEndEngineer003'): 0,
#  ('Gale Brewer', 'Architect023'): 0,
#  ('Gale Brewer', 'DataEngineer020'): 0,
#  ('Gale Brewer', 'Tester005'): 0,
#  ('Gale Brewer', 'FrontEndEngineer005'): 0,
#  ('Gale Brewer', 'BackEndEngineer028'): 0,
#  ('Gale Brewer', 'Tester026'): 0,
#  ('Gale Brewer', 'Tester032'): 0,
#  ('Gale Brewer', 'DataEngineer021'): 0,
#  ('Gale Brewer', 'DataEngineer004'): 0,
#  ('Gale Brewer', 'BackEndEngineer023'): 0,
#  ('Gale Brewer', 'BackEndEngineer029'): 0,
#  ('Gale Brewer', 'FrontEndEngineer030'): 0,
#  ('Gale Brewer', 'DataScientist030'): 0,
#  ('Gale Brewer', 'DataEngineer012'): 0,
#  ('Gale Brewer', 'FrontEndEngineer009'): 0,
#  ('Gale Brewer', 'FrontEndEngineer002'): 0,
#  ('Gale Brewer', 'DataScientist028'): 0,
#  ('Gale Brewer', 'FrontEndEngineer027'): 0,
#  ('Gale Brewer', 'BackEndEngineer009'): 0,
#  ('Gale Brewer', 'FrontEndEngineer006'): 0,
#  ('Gale Brewer', 'BackEndEngineer021'): 0,
#  ('Gale Brewer', 'FrontEndEngineer016'): 0,
#  ('Gale Brewer', 'Architect010'): 0,
#  ('Gale Brewer', 'BackEndEngineer006'): 0,
#  ('Gale Brewer', 'DataScientist023'): 0,
#  ('Gale Brewer', 'DataEngineer014'): 0,
#  ('Gale Brewer', 'DataScientist020'): 0,
#  ('Gale Brewer', 'Architect008'): 0,
#  ('Gale Brewer', 'Architect012'): 0,
#  ('Gale Brewer', 'FrontEndEngineer035'): 0,
#  ('Jason Kroesing', 'Tester034'): 0,
#  ('Jason Kroesing', 'DataScientist006'): 0,
#  ('Jason Kroesing', 'DataEngineer023'): 0,
#  ('Jason Kroesing', 'DataEngineer016'): 0,
#  ('Jason Kroesing', 'BackEndEngineer014'): 0,
#  ('Jason Kroesing', 'Tester036'): 0,
#  ('Jason Kroesing', 'DataEngineer025'): 0,
#  ('Jason Kroesing', 'DataScientist027'): 0,
#  ('Jason Kroesing', 'DataEngineer010'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer001'): 0,
#  ('Jason Kroesing', 'Architect009'): 0,
#  ('Jason Kroesing', 'BackEndEngineer015'): 0,
#  ('Jason Kroesing', 'Architect028'): 0,
#  ('Jason Kroesing', 'DataScientist034'): 0,
#  ('Jason Kroesing', 'Tester002'): 0,
#  ('Jason Kroesing', 'BackEndEngineer005'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer015'): 0,
#  ('Jason Kroesing', 'BackEndEngineer022'): 0,
#  ('Jason Kroesing', 'DataScientist007'): 0,
#  ('Jason Kroesing', 'Architect014'): 0,
#  ('Jason Kroesing', 'DataEngineer007'): 0,
#  ('Jason Kroesing', 'Architect017'): 0,
#  ('Jason Kroesing', 'Tester025'): 0,
#  ('Jason Kroesing', 'DataScientist031'): 0,
#  ('Jason Kroesing', 'DataEngineer018'): 0,
#  ('Jason Kroesing', 'DataScientist012'): 0,
#  ('Jason Kroesing', 'DataEngineer017'): 0,
#  ('Jason Kroesing', 'DataScientist021'): 0,
#  ('Jason Kroesing', 'DataEngineer024'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer026'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer024'): 0,
#  ('Jason Kroesing', 'Architect020'): 0,
#  ('Jason Kroesing', 'Architect027'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer012'): 0,
#  ('Jason Kroesing', 'DataEngineer009'): 0,
#  ('Jason Kroesing', 'DataEngineer002'): 0,
#  ('Jason Kroesing', 'BackEndEngineer017'): 0,
#  ('Jason Kroesing', 'Tester031'): 0,
#  ('Jason Kroesing', 'BackEndEngineer030'): 0,
#  ('Jason Kroesing', 'DataScientist032'): 0,
#  ('Jason Kroesing', 'Tester020'): 0,
#  ('Jason Kroesing', 'Tester003'): 0,
#  ('Jason Kroesing', 'Architect025'): 0,
#  ('Jason Kroesing', 'Architect011'): 0,
#  ('Jason Kroesing', 'Architect019'): 0,
#  ('Jason Kroesing', 'BackEndEngineer010'): 0,
#  ('Jason Kroesing', 'Tester027'): 0,
#  ('Jason Kroesing', 'Tester012'): 0,
#  ('Jason Kroesing', 'Tester022'): 0,
#  ('Jason Kroesing', 'Tester033'): 0,
#  ('Jason Kroesing', 'Architect024'): 0,
#  ('Jason Kroesing', 'BackEndEngineer003'): 0,
#  ('Jason Kroesing', 'DataScientist024'): 0,
#  ('Jason Kroesing', 'Architect026'): 0,
#  ('Jason Kroesing', 'Tester028'): 0,
#  ('Jason Kroesing', 'DataScientist011'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer029'): 0,
#  ('Jason Kroesing', 'BackEndEngineer013'): 0,
#  ('Jason Kroesing', 'DataEngineer019'): 0,
#  ('Jason Kroesing', 'Tester023'): 1,
#  ('Jason Kroesing', 'DataScientist017'): 0,
#  ('Jason Kroesing', 'Architect029'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer004'): 0,
#  ('Jason Kroesing', 'DataScientist025'): 0,
#  ('Jason Kroesing', 'DataScientist026'): 0,
#  ('Jason Kroesing', 'Tester001'): 0,
#  ('Jason Kroesing', 'BackEndEngineer016'): 0,
#  ('Jason Kroesing', 'BackEndEngineer004'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer031'): 0,
#  ('Jason Kroesing', 'DataScientist008'): 0,
#  ('Jason Kroesing', 'DataScientist035'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer011'): 0,
#  ('Jason Kroesing', 'Tester009'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer025'): 0,
#  ('Jason Kroesing', 'DataEngineer011'): 0,
#  ('Jason Kroesing', 'Tester015'): 0,
#  ('Jason Kroesing', 'DataEngineer026'): 0,
#  ('Jason Kroesing', 'BackEndEngineer024'): 0,
#  ('Jason Kroesing', 'DataScientist010'): 0,
#  ('Jason Kroesing', 'Tester029'): 0,
#  ('Jason Kroesing', 'DataScientist015'): 0,
#  ('Jason Kroesing', 'Tester035'): 0,
#  ('Jason Kroesing', 'DataEngineer001'): 0,
#  ('Jason Kroesing', 'BackEndEngineer011'): 0,
#  ('Jason Kroesing', 'Tester006'): 0,
#  ('Jason Kroesing', 'Tester011'): 0,
#  ('Jason Kroesing', 'BackEndEngineer008'): 0,
#  ('Jason Kroesing', 'BackEndEngineer012'): 0,
#  ('Jason Kroesing', 'Tester016'): 0,
#  ('Jason Kroesing', 'Tester013'): 0,
#  ('Jason Kroesing', 'DataScientist033'): 0,
#  ('Jason Kroesing', 'Tester007'): 0,
#  ('Jason Kroesing', 'DataScientist036'): 0,
#  ('Jason Kroesing', 'Tester017'): 0,
#  ('Jason Kroesing', 'DataEngineer013'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer018'): 0,
#  ('Jason Kroesing', 'DataScientist022'): 0,
#  ('Jason Kroesing', 'Tester018'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer034'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer017'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer023'): 0,
#  ('Jason Kroesing', 'Architect015'): 0,
#  ('Jason Kroesing', 'Architect005'): 0,
#  ('Jason Kroesing', 'BackEndEngineer027'): 0,
#  ('Jason Kroesing', 'Architect003'): 0,
#  ('Jason Kroesing', 'Tester004'): 0,
#  ('Jason Kroesing', 'DataScientist013'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer013'): 0,
#  ('Jason Kroesing', 'BackEndEngineer002'): 0,
#  ('Jason Kroesing', 'Architect030'): 0,
#  ('Jason Kroesing', 'Tester030'): 0,
#  ('Jason Kroesing', 'Architect002'): 0,
#  ('Jason Kroesing', 'DataScientist019'): 0,
#  ('Jason Kroesing', 'DataEngineer022'): 0,
#  ('Jason Kroesing', 'Tester024'): 0,
#  ('Jason Kroesing', 'Tester021'): 0,
#  ('Jason Kroesing', 'BackEndEngineer019'): 0,
#  ('Jason Kroesing', 'DataEngineer008'): 0,
#  ('Jason Kroesing', 'DataScientist003'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer021'): 0,
#  ('Jason Kroesing', 'DataEngineer015'): 0,
#  ('Jason Kroesing', 'Tester014'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer033'): 0,
#  ('Jason Kroesing', 'BackEndEngineer018'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer007'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer008'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer020'): 0,
#  ('Jason Kroesing', 'BackEndEngineer007'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer019'): 0,
#  ('Jason Kroesing', 'Architect034'): 0,
#  ('Jason Kroesing', 'DataScientist029'): 0,
#  ('Jason Kroesing', 'Architect001'): 0,
#  ('Jason Kroesing', 'BackEndEngineer001'): 0,
#  ('Jason Kroesing', 'Architect007'): 0,
#  ('Jason Kroesing', 'Architect031'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer028'): 0,
#  ('Jason Kroesing', 'DataScientist002'): 0,
#  ('Jason Kroesing', 'BackEndEngineer026'): 0,
#  ('Jason Kroesing', 'Tester010'): 0,
#  ('Jason Kroesing', 'Tester019'): 0,
#  ('Jason Kroesing', 'DataEngineer006'): 0,
#  ('Jason Kroesing', 'Architect018'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer010'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer022'): 0,
#  ('Jason Kroesing', 'DataEngineer005'): 0,
#  ('Jason Kroesing', 'DataEngineer003'): 0,
#  ('Jason Kroesing', 'Architect006'): 0,
#  ('Jason Kroesing', 'DataScientist016'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer014'): 0,
#  ('Jason Kroesing', 'Tester038'): 0,
#  ('Jason Kroesing', 'Architect022'): 0,
#  ('Jason Kroesing', 'BackEndEngineer025'): 0,
#  ('Jason Kroesing', 'DataScientist001'): 0,
#  ('Jason Kroesing', 'Tester008'): 0,
#  ('Jason Kroesing', 'DataScientist005'): 0,
#  ('Jason Kroesing', 'DataScientist004'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer032'): 0,
#  ('Jason Kroesing', 'Architect016'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer036'): 0,
#  ('Jason Kroesing', 'DataScientist014'): 0,
#  ('Jason Kroesing', 'Architect004'): 0,
#  ('Jason Kroesing', 'BackEndEngineer020'): 0,
#  ('Jason Kroesing', 'Tester037'): 0,
#  ('Jason Kroesing', 'Architect032'): 0,
#  ('Jason Kroesing', 'Architect033'): 0,
#  ('Jason Kroesing', 'DataScientist018'): 0,
#  ('Jason Kroesing', 'Architect021'): 0,
#  ('Jason Kroesing', 'Architect013'): 0,
#  ('Jason Kroesing', 'DataScientist009'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer003'): 0,
#  ('Jason Kroesing', 'Architect023'): 0,
#  ('Jason Kroesing', 'DataEngineer020'): 0,
#  ('Jason Kroesing', 'Tester005'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer005'): 0,
#  ('Jason Kroesing', 'BackEndEngineer028'): 0,
#  ('Jason Kroesing', 'Tester026'): 0,
#  ('Jason Kroesing', 'Tester032'): 0,
#  ('Jason Kroesing', 'DataEngineer021'): 0,
#  ('Jason Kroesing', 'DataEngineer004'): 0,
#  ('Jason Kroesing', 'BackEndEngineer023'): 0,
#  ('Jason Kroesing', 'BackEndEngineer029'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer030'): 0,
#  ('Jason Kroesing', 'DataScientist030'): 0,
#  ('Jason Kroesing', 'DataEngineer012'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer009'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer002'): 0,
#  ('Jason Kroesing', 'DataScientist028'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer027'): 0,
#  ('Jason Kroesing', 'BackEndEngineer009'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer006'): 0,
#  ('Jason Kroesing', 'BackEndEngineer021'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer016'): 0,
#  ('Jason Kroesing', 'Architect010'): 0,
#  ('Jason Kroesing', 'BackEndEngineer006'): 0,
#  ('Jason Kroesing', 'DataScientist023'): 0,
#  ('Jason Kroesing', 'DataEngineer014'): 0,
#  ('Jason Kroesing', 'DataScientist020'): 0,
#  ('Jason Kroesing', 'Architect008'): 0,
#  ('Jason Kroesing', 'Architect012'): 0,
#  ('Jason Kroesing', 'FrontEndEngineer035'): 0,
#  ...}

# %% [markdown]
# # Get Optimal Solution thru Gurobi implementation

# %%
def optimize_gurobi(num_resources, num_jobs, score_mu, score_sigma, seed, roles, budget, job_gap_penalty):
    '''    
    call a function to generate random resources, jobs, assignmnet scores and costs
    and selects the optmial resource-job combinations to maximize performance score 
    with three contraints of budget, resource assignmnet to at most one job and
    job assigmnet to at most one resource
    
    '''
    res, job, ms, cst = generate_scenario(num_resources, num_jobs, score_mu, score_sigma, seed, roles) 
    
    
    m = gp.Model("RAP")
    assign = m.addVars(ms.keys(), vtype=GRB.BINARY, name="assign")
    g = m.addVars(job, name="gap")
    m.addConstrs((assign.sum("*", j) + g[j]  == 1 for j in job), name="demand")
    m.addConstrs((assign.sum(r, "*") <= 1 for r in res), name="supply")
    m.addConstr(assign.prod(cst) <= budget, name="Budget")
    job_gap_penalty = 101 # penatly of not filling a job 
    m.setObjective(assign.prod(ms) -job_gap_penalty*g.sum(), GRB.MAXIMIZE)

    return m.optimize()

# %%
optimized_model = optimize(
    num_resources=200, 
    num_jobs=200,
    score_mu=50, 
    score_sigma=15, 
    seed=10101, 
    roles=None, 
    budget=200, 
    job_gap_penalty=101
        )
# Out:
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 401 rows, 40200 columns and 120200 nonzeros
# Model fingerprint: 0x2db8da98
# Variable types: 0 continuous, 40200 integer (40200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 8.080000e+08
# Presolve time: 0.14s
# Presolved: 401 rows, 40200 columns, 120200 nonzeros
# Variable types: 0 continuous, 40200 integer (40200 binary)
#
# Root relaxation: objective -1.631200e+04, 600 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    -16312.00000 -16312.000  0.00%     -    0s
#
# Explored 0 nodes (600 simplex iterations) in 0.35 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -16312 8.08e+08
# No other solutions better than -16312
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.631200000000e+04, best bound -1.631200000000e+04, gap 0.0000%
# status:  optimal
# optimal value:  16312.0
# Number of unfilled jobs:  0
